# %% [markdown]
# <hr>
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)<br>
# <img align="left" width="40%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" \><br><br>
# <hr>

# %% [markdown]
# #### Animation of frames with some HTML/JavaScript

# %% [markdown]
# It uses a HTML template adapted from the work of Jake Vanderplas https://github.com/jakevdp/JSAnimation
# and modified by the jinja2 engine.
#
# Control can be done with variables:
#   - listFrames (local or remote files)
#   - interval
#
# The template carries embedded icons as base64 png images.
# Frames are not embedded into the notebook.

# %%
import IPython.display
import jinja2
import glob

def display_animation(animID, files, interval=200, style=False):
    env = jinja2.Environment(loader=jinja2.FileSystemLoader('.'))
    template = env.get_template('animation_template.html')

    try:            # frames are local and can be expanded
        listFrames = sorted(glob.glob(files))
    except:         # frames are remote ressources
        listFrames = files
    htmlSrc = template.render(ID=animID, listFrames=listFrames, interval=interval, style=style)
    
    return IPython.display.HTML(htmlSrc)

# %% [markdown]
# ####Let's animate frames stored locally taken from early work in motion-picture from photographer Eadweard Muybridge (1830-1904) http://en.wikipedia.org/wiki/Eadweard_Muybridge

# %%
display_animation("animBird", "frames0/frame_*.png")
# Out:
# <script language="javascript">
#
#   /* ======================================================================== */
#   /*  Copied and adpated from https://github.com/jakevdp/JSAnimation          */
#   /*  Thanks to Jake Vanderplas                                               */
#   /*  Changes:                                                                */
#   /*    - now defined as a jinja2 template with variables:                    */
#   /*             - listFrames                                                 */
#   /*             - interval                                                   */
#   /*    - now has embedded icons as base64 png images                         */
#   /*    - anim_frame_slider onchange --> oninput event                        */
#   /*                                                                          */
#   /*   Patrick Brockmann - https://github.com/PBrockmann                      */
#   /* ======================================================================== */
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = 200;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="anim_img_animBird" >
#     <br>
#     <input id="anim_frame_slider_animBird" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" oninput="anim_animBird.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim_animBird.slower()">&#8211;</button>
#     <button onclick="anim_animBird.first_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animBird.previous_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animBird.reverse_animation()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animBird.pause_animation()"><img src="..."/></button>
#     <button onclick="anim_animBird.play_animation()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animBird.next_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animBird.last_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animBird.faster()">+</button>
#   <form action="#n" name="loop_select_animBird" class="anim_control">
#     <input type="radio" name="state" value="once"> Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect"> Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   var img_id = "anim_img_animBird";
#   var slider_id = "anim_frame_slider_animBird";
#   var loop_select_id = "loop_select_animBird";
#   var frames = ['frames0/frame_000.png', 'frames0/frame_001.png', 'frames0/frame_002.png', 'frames0/frame_003.png', 'frames0/frame_004.png', 'frames0/frame_005.png', 'frames0/frame_006.png', 'frames0/frame_007.png', 'frames0/frame_008.png', 'frames0/frame_009.png', 'frames0/frame_010.png', 'frames0/frame_011.png', 'frames0/frame_012.png'];
#
#   /* Name of 'anim' variable should be unique, and match what's specified
#      in the template above */
#    anim_animBird = new Animation(frames, img_id, slider_id, loop_select_id);
# </script>

# %% [markdown]
# ####It also works with remote images
# Stroboscopic images from http://en.wikipedia.org/wiki/Harold_Eugene_Edgerton
# (http://edgerton-digital-collections.org)

# %%
remoteFiles = [ "http://webmuseum.mit.edu/images/DIAmed/HEE-NC-350%02d.L.jpg" %i for i in range(7,15)]
display_animation("animDrop", remoteFiles, style="width:200px;height:300px;")
# Out:
# <script language="javascript">
#
#   /* ======================================================================== */
#   /*  Copied and adpated from https://github.com/jakevdp/JSAnimation          */
#   /*  Thanks to Jake Vanderplas                                               */
#   /*  Changes:                                                                */
#   /*    - now defined as a jinja2 template with variables:                    */
#   /*             - listFrames                                                 */
#   /*             - interval                                                   */
#   /*    - now has embedded icons as base64 png images                         */
#   /*    - anim_frame_slider onchange --> oninput event                        */
#   /*                                                                          */
#   /*   Patrick Brockmann - https://github.com/PBrockmann                      */
#   /* ======================================================================== */
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = 200;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="anim_img_animDrop"  style="width:200px;height:300px;" >
#     <br>
#     <input id="anim_frame_slider_animDrop" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" oninput="anim_animDrop.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim_animDrop.slower()">&#8211;</button>
#     <button onclick="anim_animDrop.first_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animDrop.previous_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animDrop.reverse_animation()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animDrop.pause_animation()"><img src="..."/></button>
#     <button onclick="anim_animDrop.play_animation()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animDrop.next_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animDrop.last_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animDrop.faster()">+</button>
#   <form action="#n" name="loop_select_animDrop" class="anim_control">
#     <input type="radio" name="state" value="once"> Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect"> Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   var img_id = "anim_img_animDrop";
#   var slider_id = "anim_frame_slider_animDrop";
#   var loop_select_id = "loop_select_animDrop";
#   var frames = ['http://webmuseum.mit.edu/images/DIAmed/HEE-NC-35007.L.jpg', 'http://webmuseum.mit.edu/images/DIAmed/HEE-NC-35008.L.jpg', 'http://webmuseum.mit.edu/images/DIAmed/HEE-NC-35009.L.jpg', 'http://webmuseum.mit.edu/images/DIAmed/HEE-NC-35010.L.jpg', 'http://webmuseum.mit.edu/images/DIAmed/HEE-NC-35011.L.jpg', 'http://webmuseum.mit.edu/images/DIAmed/HEE-NC-35012.L.jpg', 'http://webmuseum.mit.edu/images/DIAmed/HEE-NC-35013.L.jpg', 'http://webmuseum.mit.edu/images/DIAmed/HEE-NC-35014.L.jpg'];
#
#   /* Name of 'anim' variable should be unique, and match what's specified
#      in the template above */
#    anim_animDrop = new Animation(frames, img_id, slider_id, loop_select_id);
# </script>

# %% [markdown]
# ####Now create frames by using ferretmagic extension
# http://nbviewer.ipython.org/github/PBrockmann/ipython-ferretmagic/blob/master/ferretmagic_01_Discovering.ipynb

# %%
# %load_ext ferretmagic

# %%
# %%ferret
# use levitus_climatology

# %% [markdown]
# #####Create frames

# %%
import os, shutil
shutil.rmtree("frames1", ignore_errors=True)
os.mkdir("frames1")
for i in range(1,20,2):
    # use very small size --> so not displayed (don't know why but fit to purpose)
    # %ferret_run -q -s 20,20 'shade/lev=(-inf)(-2,28,1)(inf) temp[k=%d] ; go land ; frame/file="frames1/frame_%03d.png"/xpixels=500' % (i, i)

# %% [markdown]
# #####Display frames as thumbnails

# %%
import IPython.display
import glob

listFrames=sorted(glob.glob('frames1/frame_*.png'))
htmlSrc=''.join( ["<img style='width: 120px; margin: 0px; float: left; border: 1px solid black;' src='%s' />" % f 
                 for f in listFrames ])
IPython.display.HTML(htmlSrc)
# Out:
# <img style='width: 120px; margin: 0px; float: left; border: 1px solid black;' src='frames1/frame_001.png' /><img style='width: 120px; margin: 0px; float: left; border: 1px solid black;' src='frames1/frame_003.png' /><img style='width: 120px; margin: 0px; float: left; border: 1px solid black;' src='frames1/frame_005.png' /><img style='width: 120px; margin: 0px; float: left; border: 1px solid black;' src='frames1/frame_007.png' /><img style='width: 120px; margin: 0px; float: left; border: 1px solid black;' src='frames1/frame_009.png' /><img style='width: 120px; margin: 0px; float: left; border: 1px solid black;' src='frames1/frame_011.png' /><img style='width: 120px; margin: 0px; float: left; border: 1px solid black;' src='frames1/frame_013.png' /><img style='width: 120px; margin: 0px; float: left; border: 1px solid black;' src='frames1/frame_015.png' /><img style='width: 120px; margin: 0px; float: left; border: 1px solid black;' src='frames1/frame_017.png' /><img style='width: 120px; margin: 0px; float: left; border: 1px solid black;' src='frames1/frame_019.png' />

# %% [markdown]
# #####Display the animation

# %%
display_animation("animTemp", "frames1/frame_*.png")
# Out:
# <script language="javascript">
#
#   /* ======================================================================== */
#   /*  Copied and adpated from https://github.com/jakevdp/JSAnimation          */
#   /*  Thanks to Jake Vanderplas                                               */
#   /*  Changes:                                                                */
#   /*    - now defined as a jinja2 template with variables:                    */
#   /*             - listFrames                                                 */
#   /*             - interval                                                   */
#   /*    - now has embedded icons as base64 png images                         */
#   /*    - anim_frame_slider onchange --> oninput event                        */
#   /*                                                                          */
#   /*   Patrick Brockmann - https://github.com/PBrockmann                      */
#   /* ======================================================================== */
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = 200;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="anim_img_animTemp" >
#     <br>
#     <input id="anim_frame_slider_animTemp" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" oninput="anim_animTemp.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim_animTemp.slower()">&#8211;</button>
#     <button onclick="anim_animTemp.first_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animTemp.previous_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animTemp.reverse_animation()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animTemp.pause_animation()"><img src="..."/></button>
#     <button onclick="anim_animTemp.play_animation()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animTemp.next_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animTemp.last_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animTemp.faster()">+</button>
#   <form action="#n" name="loop_select_animTemp" class="anim_control">
#     <input type="radio" name="state" value="once"> Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect"> Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   var img_id = "anim_img_animTemp";
#   var slider_id = "anim_frame_slider_animTemp";
#   var loop_select_id = "loop_select_animTemp";
#   var frames = ['frames1/frame_001.png', 'frames1/frame_003.png', 'frames1/frame_005.png', 'frames1/frame_007.png', 'frames1/frame_009.png', 'frames1/frame_011.png', 'frames1/frame_013.png', 'frames1/frame_015.png', 'frames1/frame_017.png', 'frames1/frame_019.png'];
#
#   /* Name of 'anim' variable should be unique, and match what's specified
#      in the template above */
#    anim_animTemp = new Animation(frames, img_id, slider_id, loop_select_id);
# </script>

# %% [markdown]
# #####Let's create another directory with other frames for another animation

# %%
import os, shutil
shutil.rmtree("frames2", ignore_errors=True)
os.mkdir("frames2")
for i in range(1,20,2):
    # use very small size --> so not displayed (don't know why but fit to purpose)
    # %ferret_run -q -s 20,20 'shade/lev=(-inf)(33,35,0.1)(inf) salt[k=%d] ; go land ; frame/file="frames2/frame_%03d.png"/xpixels=500' % (i, i)

# %%
display_animation("animSalt", "frames2/frame_*.png")
# Out:
# <script language="javascript">
#
#   /* ======================================================================== */
#   /*  Copied and adpated from https://github.com/jakevdp/JSAnimation          */
#   /*  Thanks to Jake Vanderplas                                               */
#   /*  Changes:                                                                */
#   /*    - now defined as a jinja2 template with variables:                    */
#   /*             - listFrames                                                 */
#   /*             - interval                                                   */
#   /*    - now has embedded icons as base64 png images                         */
#   /*    - anim_frame_slider onchange --> oninput event                        */
#   /*                                                                          */
#   /*   Patrick Brockmann - https://github.com/PBrockmann                      */
#   /* ======================================================================== */
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = 200;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="anim_img_animSalt" >
#     <br>
#     <input id="anim_frame_slider_animSalt" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" oninput="anim_animSalt.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim_animSalt.slower()">&#8211;</button>
#     <button onclick="anim_animSalt.first_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animSalt.previous_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animSalt.reverse_animation()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animSalt.pause_animation()"><img src="..."/></button>
#     <button onclick="anim_animSalt.play_animation()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animSalt.next_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animSalt.last_frame()"><img src="data:image/png;base64,..."/></button>
#     <button onclick="anim_animSalt.faster()">+</button>
#   <form action="#n" name="loop_select_animSalt" class="anim_control">
#     <input type="radio" name="state" value="once"> Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect"> Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   var img_id = "anim_img_animSalt";
#   var slider_id = "anim_frame_slider_animSalt";
#   var loop_select_id = "loop_select_animSalt";
#   var frames = ['frames2/frame_001.png', 'frames2/frame_003.png', 'frames2/frame_005.png', 'frames2/frame_007.png', 'frames2/frame_009.png', 'frames2/frame_011.png', 'frames2/frame_013.png', 'frames2/frame_015.png', 'frames2/frame_017.png', 'frames2/frame_019.png'];
#
#   /* Name of 'anim' variable should be unique, and match what's specified
#      in the template above */
#    anim_animSalt = new Animation(frames, img_id, slider_id, loop_select_id);
# </script>
